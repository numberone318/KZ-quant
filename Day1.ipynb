# %%
# Day1：中信银行股价 + 20日均线  —— CFA 41岁转量化第一天
import pandas as pd
import numpy as np
import akshare as ak
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# 第1步：下载中信银行从2020年至今的前复权日线数据
df = ak.stock_zh_a_hist(symbol="601998", start_date="20200101", adjust="qfq")

# 第2步：计算20日均线
df['MA20'] = df['收盘'].rolling(window=20).mean()

# 第3步：画图
plt.figure(figsize=(14,7))
plt.plot(df['日期'], df['收盘'], label='中信银行收盘价', linewidth=1.2)
plt.plot(df['日期'], df['MA20'], label='20日均线', color='orange')
plt.title('中信银行(601939) 2020-2025股价走势 by KZ', fontsize=18)
plt.xlabel('日期'); plt.ylabel('价格(元)')
plt.legend(); plt.grid(); plt.tight_layout()
plt.show()

# 第4步：保存数据到你电脑（以后要用）
df.to_csv('C:/Users/Administrator/Desktop/中信银行历史数据.csv', 
          index=False, encoding='utf-8-sig')
print("Day1完成！数据已保存到桌面！")
# Out:
# Day1完成！数据已保存到桌面！
